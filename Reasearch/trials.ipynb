# %%
from src.constants import CONFIG_FILE_PATH, PARAMS_FILE_PATH

print(CONFIG_FILE_PATH)
print(PARAMS_FILE_PATH)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.constants import CONFIG_FILE_PATH, PARAMS_FILE_PATH
#       3 print(CONFIG_FILE_PATH)
#       4 print(PARAMS_FILE_PATH)
#
# ModuleNotFoundError: No module named 'src'

# %%
from datasets import load_dataset

dataset = load_dataset("Aarif1430/english-to-hindi")

# %%
dataset
dataset.save_to_disk("artifacts/data_ingestion/translate")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/127705 [00:00<?, ? examples/s]

# %%
import pandas
train_df = dataset["train"].to_pandas()
train_df.to_csv(
    "artifacts/data_ingestion/train.csv",
    index=False,
    encoding="utf-8"
)

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['english_sentence', 'hindi_sentence'],
#         num_rows: 127705
#     })
# })
